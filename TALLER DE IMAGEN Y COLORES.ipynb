# %%
import cv2 as cv

# %%
miimagen=cv.imread("petro")

# %%
# !ls
# Out:
# sample_data

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-b6179cf5-bd68-4559-ae52-dad2a8606178" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b6179cf5-bd68-4559-ae52-dad2a8606178">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving petro.jpg to petro.jpg

# %%
# !ls
# Out:
# petro.jpg  sample_data

# %%
imagen=cv.imread("petro.jpg")

# %%
print(imagen)
# Out:
# [[[ 94  91  87]
#   [ 94  91  87]
#   [ 94  91  87]
#   ...
#   [ 74  71  67]
#   [ 74  71  67]
#   [ 74  71  67]]
#
#  [[ 94  91  87]
#   [ 94  91  87]
#   [ 94  91  87]
#   ...
#   [ 74  71  67]
#   [ 74  71  67]
#   [ 74  71  67]]
#
#  [[ 94  91  87]
#   [ 94  91  87]
#   [ 94  91  87]
#   ...
#   [ 74  71  67]
#   [ 74  71  67]
#   [ 74  71  67]]
#
#  ...
#
#  [[105  99  92]
#   [105  99  92]
#   [105  99  92]
#   ...
#   [ 86  83  78]
#   [ 87  82  79]
#   [ 86  83  78]]
#
#  [[105  99  92]
#   [105  99  92]
#   [105  99  92]
#   ...
#   [ 86  83  79]
#   [ 86  83  79]
#   [ 86  83  79]]
#
#  [[105  99  92]
#   [105  99  92]
#   [105  99  92]
#   ...
#   [ 86  83  79]
#   [ 86  83  79]
#   [ 86  83  79]]]

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(imagen)

# %%
imagen1=cv.cvtColor(imagen,cv.COLOR_BGR2RGB) 
plt.figure(figsize=(8,9))
plt.imshow(imagen1)
plt.show()

# %%
img2=cv.cvtColor(imagen,cv.COLOR_BGR2GRAY)
plt.figure(figsize=(8,9))
plt.imshow(img2)
plt.show()

# %%
r,g,b=cv.split(imagen)
plt.figure(figsize=(28,19))
plt.subplot(131)
im=plt.imshow(b,cmap="Blues")
plt.colorbar(im,fraction=0.029, pad=0.04)
plt.subplot(132)
im=plt.imshow(r,cmap="Reds")
plt.colorbar(im,fraction=0.029, pad=0.04)
plt.subplot(133)
im=plt.imshow(g,cmap="Greens")
plt.colorbar(im,fraction=0.029, pad=0.04)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(b.ravel(),bins=256,range=(0,256),color='b',label='blue')
plt.hist(g.ravel(),bins=256,range=(0,256),color='g',label='green')
plt.hist(r.ravel(),bins=256,range=(0,256),color='r',label='red')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(b.ravel(),bins=256,range=(0,256),color='b',label='blue')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(g.ravel(),bins=256,range=(0,256),color='g',label='green')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(r.ravel(),bins=256,range=(0,256),color='r',label='red')
plt.legend()
plt.show()
